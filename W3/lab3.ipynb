# %%
import pandas as pd

# %%
column_names= ["ID","Name","Age","Weight","m0006","m0612","m1218","f006","f0612","f1218"]
patientheartrate = pd.read_csv("patient_heart_rate.csv", names = column_names, on_bad_lines='skip')
patientheartrate
# Out:
#       ID            Name   Age      Weight m0006 m0612 m1218 f006 f0612 f1218
# 0    1.0    Mickéy Mousé  56.0       70kgs    72    69    71    -     -     -
# 1    2.0     Donald Duck  34.0   154.89lbs     -     -     -   85    84    76
# 2    3.0      Mini Mouse  16.0         NaN     -     -     -   65    69    72
# 3    4.0  Scrooge McDuck   NaN       78kgs    78    79    72    -     -     -
# 4    5.0    Pink Panther  54.0  198.658lbs     -     -     -   69   NaN    75
# 5    6.0     Huey McDuck  52.0      189lbs     -     -     -   68    75    72
# 6    7.0    Dewey McDuck  19.0       56kgs     -     -     -   71    78    75
# 7    8.0      Scööpy Doo  32.0       78kgs    78    76    75    -     -     -
# 8    NaN             NaN   NaN         NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 9    NaN             NaN   NaN         NaN   NaN   NaN   NaN  NaN   NaN   NaN
# 10   9.0     Huey McDuck  52.0      189lbs     -     -     -   68    75    72
# 11  10.0    Louie McDuck  12.0       45kgs     -     -     -   92    95    87
# 12  11.0       Henry Nam   NaN       60kgs    78    75    72    -     -     -
# 13  12.0     Michel Long  34.0         NaN    65    67    55    -     -     -
# 14  13.0      Tana Ricky   NaN         NaN     -     -     -   68    72    70
# 15  15.0             NaN  52.0      180lbs     -     -     -   68    75    72

# %%
patientheartrate[['Firstname','Lastname']] = patientheartrate['Name'].str.split(expand = True)
patientheartrate = patientheartrate.drop('Name', axis=1)

patientheartrate
# Out:
#       ID   Age      Weight m0006 m0612 m1218 f006 f0612 f1218 Firstname  \
# 0    1.0  56.0       70kgs    72    69    71    -     -     -    Mickéy
# 1    2.0  34.0   154.89lbs     -     -     -   85    84    76    Donald
# 2    3.0  16.0         NaN     -     -     -   65    69    72      Mini
# 3    4.0   NaN       78kgs    78    79    72    -     -     -   Scrooge
# 4    5.0  54.0  198.658lbs     -     -     -   69   NaN    75      Pink
# 5    6.0  52.0      189lbs     -     -     -   68    75    72      Huey
# 6    7.0  19.0       56kgs     -     -     -   71    78    75     Dewey
# 7    8.0  32.0       78kgs    78    76    75    -     -     -    Scööpy
# 8    NaN   NaN         NaN   NaN   NaN   NaN  NaN   NaN   NaN       NaN
# 9    NaN   NaN         NaN   NaN   NaN   NaN  NaN   NaN   NaN       NaN
# 10   9.0  52.0      189lbs     -     -     -   68    75    72      Huey
# 11  10.0  12.0       45kgs     -     -     -   92    95    87     Louie
# 12  11.0   NaN       60kgs    78    75    72    -     -     -     Henry
# 13  12.0  34.0         NaN    65    67    55    -     -     -    Michel
# 14  13.0   NaN         NaN     -     -     -   68    72    70      Tana
# 15  15.0  52.0      180lbs     -     -     -   68    75    72       NaN
#
#    Lastname
# 0     Mousé
# 1      Duck
# 2     Mouse
# 3    McDuck
# 4   Panther
# 5    McDuck
# 6    McDuck
# 7       Doo
# 8       NaN
# 9       NaN
# 10   McDuck
# 11   McDuck
# 12      Nam
# 13     Long
# 14    Ricky
# 15      NaN

# %%
weight = patientheartrate['Weight']
for i in range(len(weight)):
    x=str(weight[i])
    if "lbs" in x[-3:]:
        x=x[:-3:]
        float_x = float(x)
        y = int(float_x/2.205)
        y = str(y)+"kgs"
        weight[i] = y
patientheartrate
# Out:
#       ID   Age Weight m0006 m0612 m1218 f006 f0612 f1218 Firstname Lastname
# 0    1.0  56.0  70kgs    72    69    71    -     -     -    Mickéy    Mousé
# 1    2.0  34.0  70kgs     -     -     -   85    84    76    Donald     Duck
# 2    3.0  16.0    NaN     -     -     -   65    69    72      Mini    Mouse
# 3    4.0   NaN  78kgs    78    79    72    -     -     -   Scrooge   McDuck
# 4    5.0  54.0  90kgs     -     -     -   69   NaN    75      Pink  Panther
# 5    6.0  52.0  85kgs     -     -     -   68    75    72      Huey   McDuck
# 6    7.0  19.0  56kgs     -     -     -   71    78    75     Dewey   McDuck
# 7    8.0  32.0  78kgs    78    76    75    -     -     -    Scööpy      Doo
# 8    NaN   NaN    NaN   NaN   NaN   NaN  NaN   NaN   NaN       NaN      NaN
# 9    NaN   NaN    NaN   NaN   NaN   NaN  NaN   NaN   NaN       NaN      NaN
# 10   9.0  52.0  85kgs     -     -     -   68    75    72      Huey   McDuck
# 11  10.0  12.0  45kgs     -     -     -   92    95    87     Louie   McDuck
# 12  11.0   NaN  60kgs    78    75    72    -     -     -     Henry      Nam
# 13  12.0  34.0    NaN    65    67    55    -     -     -    Michel     Long
# 14  13.0   NaN    NaN     -     -     -   68    72    70      Tana    Ricky
# 15  15.0  52.0  81kgs     -     -     -   68    75    72       NaN      NaN

# %%
import seaborn as sns
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
sns.heatmap(patientheartrate.isna(), 
            yticklabels=False, 
            cbar=True, 
            cmap='viridis')
# Out:
# <Axes: >

# %%
patientheartrate.dropna(how="all", inplace=True)
patientheartrate
# Out:
#       ID   Age Weight m0006 m0612 m1218 f006 f0612 f1218 Firstname Lastname
# 0    1.0  56.0  70kgs    72    69    71    -     -     -    Mickéy    Mousé
# 1    2.0  34.0  70kgs     -     -     -   85    84    76    Donald     Duck
# 2    3.0  16.0    NaN     -     -     -   65    69    72      Mini    Mouse
# 3    4.0   NaN  78kgs    78    79    72    -     -     -   Scrooge   McDuck
# 4    5.0  54.0  90kgs     -     -     -   69   NaN    75      Pink  Panther
# 5    6.0  52.0  85kgs     -     -     -   68    75    72      Huey   McDuck
# 6    7.0  19.0  56kgs     -     -     -   71    78    75     Dewey   McDuck
# 7    8.0  32.0  78kgs    78    76    75    -     -     -    Scööpy      Doo
# 10   9.0  52.0  85kgs     -     -     -   68    75    72      Huey   McDuck
# 11  10.0  12.0  45kgs     -     -     -   92    95    87     Louie   McDuck
# 12  11.0   NaN  60kgs    78    75    72    -     -     -     Henry      Nam
# 13  12.0  34.0    NaN    65    67    55    -     -     -    Michel     Long
# 14  13.0   NaN    NaN     -     -     -   68    72    70      Tana    Ricky
# 15  15.0  52.0  81kgs     -     -     -   68    75    72       NaN      NaN

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
sns.heatmap(patientheartrate.isna(), 
            yticklabels=False, 
            cbar=True, 
            cmap='viridis')
# Out:
# <Axes: >

# %%
patientheartrate.Firstname.replace({r'[^\x00-\x7F]+':''},regex=True)
patientheartrate.Lastname.replace({r'[^\x00-\x7F]+':''},regex=True)
patientheartrate
# Out:
#       ID   Age Weight m0006 m0612 m1218 f006 f0612 f1218 Firstname Lastname
# 0    1.0  56.0  70kgs    72    69    71    -     -     -    Mickéy    Mousé
# 1    2.0  34.0  70kgs     -     -     -   85    84    76    Donald     Duck
# 2    3.0  16.0    NaN     -     -     -   65    69    72      Mini    Mouse
# 3    4.0   NaN  78kgs    78    79    72    -     -     -   Scrooge   McDuck
# 4    5.0  54.0  90kgs     -     -     -   69   NaN    75      Pink  Panther
# 5    6.0  52.0  85kgs     -     -     -   68    75    72      Huey   McDuck
# 6    7.0  19.0  56kgs     -     -     -   71    78    75     Dewey   McDuck
# 7    8.0  32.0  78kgs    78    76    75    -     -     -    Scööpy      Doo
# 10   9.0  52.0  85kgs     -     -     -   68    75    72      Huey   McDuck
# 11  10.0  12.0  45kgs     -     -     -   92    95    87     Louie   McDuck
# 12  11.0   NaN  60kgs    78    75    72    -     -     -     Henry      Nam
# 13  12.0  34.0    NaN    65    67    55    -     -     -    Michel     Long
# 14  13.0   NaN    NaN     -     -     -   68    72    70      Tana    Ricky
# 15  15.0  52.0  81kgs     -     -     -   68    75    72       NaN      NaN

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
sns.heatmap(patientheartrate.isna(), 
            yticklabels=False, 
            cbar=True, 
            cmap='viridis')
# Out:
# <Axes: >

# %%
index_ageweightnull = patientheartrate[patientheartrate['Age'].isna() & patientheartrate['Weight'].isna()].index
index_ageweightnull
# Out:
# Index([14], dtype='int64')

# %%
patientheartrate.drop(index_ageweightnull, inplace=True)

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
sns.heatmap(patientheartrate.isna(), 
            yticklabels=False, 
            cbar=True, 
            cmap='viridis')
# Out:
# <Axes: >

# %%
patientheartrate['Age'].fillna(patientheartrate['Age'].mean(), inplace =False)
# Out:
# 0     56.000000
# 1     34.000000
# 2     16.000000
# 3     37.545455
# 4     54.000000
# 5     52.000000
# 6     19.000000
# 7     32.000000
# 10    52.000000
# 11    12.000000
# 12    37.545455
# 13    34.000000
# 15    52.000000
# Name: Age, dtype: float64

# %%
# VD 8
patientheartrate
# Out:
#       ID   Age Weight m0006 m0612 m1218 f006 f0612 f1218 Firstname Lastname
# 0    1.0  56.0  70kgs    72    69    71    -     -     -    Mickéy    Mousé
# 1    2.0  34.0  70kgs     -     -     -   85    84    76    Donald     Duck
# 2    3.0  16.0    NaN     -     -     -   65    69    72      Mini    Mouse
# 3    4.0   NaN  78kgs    78    79    72    -     -     -   Scrooge   McDuck
# 4    5.0  54.0  90kgs     -     -     -   69   NaN    75      Pink  Panther
# 5    6.0  52.0  85kgs     -     -     -   68    75    72      Huey   McDuck
# 6    7.0  19.0  56kgs     -     -     -   71    78    75     Dewey   McDuck
# 7    8.0  32.0  78kgs    78    76    75    -     -     -    Scööpy      Doo
# 10   9.0  52.0  85kgs     -     -     -   68    75    72      Huey   McDuck
# 11  10.0  12.0  45kgs     -     -     -   92    95    87     Louie   McDuck
# 12  11.0   NaN  60kgs    78    75    72    -     -     -     Henry      Nam
# 13  12.0  34.0    NaN    65    67    55    -     -     -    Michel     Long
# 15  15.0  52.0  81kgs     -     -     -   68    75    72       NaN      NaN

# %%
df = pd.melt(patientheartrate, id_vars=['ID', 'Age', 'Weight', 'Firstname', 'Lastname'], value_name="PulseRate",var_name="sex_and_time").sort_values(['ID', 'Age', 'Weight', 'Firstname', 'Lastname'])
len(df['PulseRate'])
df
# Out:
#       ID   Age Weight Firstname Lastname sex_and_time PulseRate
# 0    1.0  56.0  70kgs    Mickéy    Mousé        m0006        72
# 13   1.0  56.0  70kgs    Mickéy    Mousé        m0612        69
# 26   1.0  56.0  70kgs    Mickéy    Mousé        m1218        71
# 39   1.0  56.0  70kgs    Mickéy    Mousé         f006         -
# 52   1.0  56.0  70kgs    Mickéy    Mousé        f0612         -
# ..   ...   ...    ...       ...      ...          ...       ...
# 25  15.0  52.0  81kgs       NaN      NaN        m0612         -
# 38  15.0  52.0  81kgs       NaN      NaN        m1218         -
# 51  15.0  52.0  81kgs       NaN      NaN         f006        68
# 64  15.0  52.0  81kgs       NaN      NaN        f0612        75
# 77  15.0  52.0  81kgs       NaN      NaN        f1218        72
#
# [78 rows x 7 columns]

# %%
tmp_df= df["sex_and_time"].str.extract("(\D)(\d+)(\d{2})", expand=True)
tmp_df.columns=["Sex","hours_lower","hours_upper"]
tmp_df["Time"]=tmp_df["hours_lower"] + "-"+ tmp_df["hours_upper"]
df =pd.concat([df, tmp_df], axis=1)
df = df.drop(['sex_and_time','hours_lower','hours_upper'], axis=1)
df = df.dropna()
len(df['PulseRate'])
df.head(10)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\TuanHiep\AppData\Local\Temp\ipykernel_3108\2431502903.py:1: SyntaxWarning: invalid escape sequence '\D'
#   tmp_df= df["sex_and_time"].str.extract("(\D)(\d+)(\d{2})", expand=True)
#      ID   Age Weight Firstname Lastname PulseRate Sex   Time
# 0   1.0  56.0  70kgs    Mickéy    Mousé        72   m  00-06
# 13  1.0  56.0  70kgs    Mickéy    Mousé        69   m  06-12
# 26  1.0  56.0  70kgs    Mickéy    Mousé        71   m  12-18
# 39  1.0  56.0  70kgs    Mickéy    Mousé         -   f   0-06
# 52  1.0  56.0  70kgs    Mickéy    Mousé         -   f  06-12
# 65  1.0  56.0  70kgs    Mickéy    Mousé         -   f  12-18
# 1   2.0  34.0  70kgs    Donald     Duck         -   m  00-06
# 14  2.0  34.0  70kgs    Donald     Duck         -   m  06-12
# 27  2.0  34.0  70kgs    Donald     Duck         -   m  12-18
# 40  2.0  34.0  70kgs    Donald     Duck        85   f   0-06

# %%
# Hãy khảo sát tỉ lệ dữ liệu thiếu trên biến huyết áp. Dữ liệu bị thiếu thì hãy xử lý bằng phương pháp sau 


# 1.   Thay thế bằng giá trị trung bình liền trước và liền sau của người đó. Nếu không được thì dùng 2)
# 2.   Thay thế bằng giá trị trung bình 2 giá liền trước của người đó. Nếu không được thì dùng 3)
# 1.   Thay thế bằng giá trị trung bình 2 giá liền sau của người đó. Nếu không được thì dùng 4)
# 2.    Trung bình của các giá trị huyết áp của người đó. Nếu không được thì dùng 5)
# 1.   Trung bình của các giá trị huyết áp của nhóm giới tính. Nếu không được thì dùng 6)
# 2.   Trung bình của các giá trị dữ liệu. Nếu không được thì thay bằng mức ổn định trong y học

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
sns.heatmap(df.isna(), 
            yticklabels=False, 
            cbar=True, 
            cmap='viridis')
# Out:
# <Axes: >

# %%
df['PulseRate']= df['PulseRate'].replace({'-' : '0'}, regex=True)
df["PulseRate"] = df["PulseRate"].fillna('0')
len(df["PulseRate"])
# Out:
# 47

# %%
def avgPulserate(df, firstname):
    sumPulserate = 0
    nsumPulserate = 0
    for i, value in enumerate(df['Firstname']):
        if value == firstname:
            try:
                if df['PulseRate'][i] !='0':
                    sumPulserate += int(df['PulseRate'].values[i])
                    nsumPulserate += 1
            except:
                pass
    if nsumPulserate > 0:
        return str(sumPulserate/nsumPulserate)
    else:
        return 0

# %%
def isValidIndex1(index, nrows):
  return index - 1 > 0 & index + 1 < nrows

# %%
def isValidIndex2(index, nrows):
  return index + 1 < nrows & index + 2 < nrows

# %%
def isPulseRateNotNull1(index, df):
  return str(df['PulseRate'].values[index-1])!= '0' and str(df['PulseRate'].values[index+1])!= '0'

# %%
def isPulseRateNotNull2(index, df):
  return str(df['PulseRate'].values[index+1])!= '0' and str(df['PulseRate'].values[index +2])!= '0'

# %%
def isInGroup1(df, index, firstname):
  return df['Firstname'].values[index-1]== firstname and df['Firstname'].values[index +1]== firstname

# %%
def isInGroup2(df, index, firstname):
  return df['Firstname'].values[index+1]== firstname and df['Firstname'].values[index +2]== firstname

# %%
def updatePulseRatena (index, df):
  nrows = len(df['PulseRate']) -2
  newvalue = ''
  firstname = df['Firstname'].values[index]
  try:
    if isValidIndex1(index,nrows) & isPulseRateNotNull1(index, df) & isInGroup1(df, index, firstname):
      try: 
        newvalue = (int(df['PulseRate'].values[index-1]) + int(df['PulseRate'].values[index+1]))/2
      except:
        newvalue = '0'
    elif isValidIndex2(index,nrows) & isPulseRateNotNull2(index, df) & isInGroup2(df, index, firstname):
      try:
        newvalue = (int(df['PulseRate'].values[index-1]) + int(df['PulseRate'].values[index+1]))/2
      except:
        newvalue ='0'
    else:
      newvalue = avgPulserate(df, firstname)
  except:
      newvalue = avgPulserate(df, firstname)
  finally:
    pass
  return newvalue

# %%
len(df["PulseRate"])
# Out:
# 47

# %%
df
# Out:
#       ID   Age Weight Firstname Lastname PulseRate Sex   Time
# 0    1.0  56.0  70kgs    Mickéy    Mousé        72   m  00-06
# 13   1.0  56.0  70kgs    Mickéy    Mousé        69   m  06-12
# 26   1.0  56.0  70kgs    Mickéy    Mousé        71   m  12-18
# 39   1.0  56.0  70kgs    Mickéy    Mousé         0   f   0-06
# 52   1.0  56.0  70kgs    Mickéy    Mousé         0   f  06-12
# 65   1.0  56.0  70kgs    Mickéy    Mousé         0   f  12-18
# 1    2.0  34.0  70kgs    Donald     Duck         0   m  00-06
# 14   2.0  34.0  70kgs    Donald     Duck         0   m  06-12
# 27   2.0  34.0  70kgs    Donald     Duck         0   m  12-18
# 40   2.0  34.0  70kgs    Donald     Duck        85   f   0-06
# 53   2.0  34.0  70kgs    Donald     Duck        84   f  06-12
# 66   2.0  34.0  70kgs    Donald     Duck        76   f  12-18
# 4    5.0  54.0  90kgs      Pink  Panther         0   m  00-06
# 17   5.0  54.0  90kgs      Pink  Panther         0   m  06-12
# 30   5.0  54.0  90kgs      Pink  Panther         0   m  12-18
# 43   5.0  54.0  90kgs      Pink  Panther        69   f   0-06
# 69   5.0  54.0  90kgs      Pink  Panther        75   f  12-18
# 5    6.0  52.0  85kgs      Huey   McDuck         0   m  00-06
# 18   6.0  52.0  85kgs      Huey   McDuck         0   m  06-12
# 31   6.0  52.0  85kgs      Huey   McDuck         0   m  12-18
# 44   6.0  52.0  85kgs      Huey   McDuck        68   f   0-06
# 57   6.0  52.0  85kgs      Huey   McDuck        75   f  06-12
# 70   6.0  52.0  85kgs      Huey   McDuck        72   f  12-18
# 6    7.0  19.0  56kgs     Dewey   McDuck         0   m  00-06
# 19   7.0  19.0  56kgs     Dewey   McDuck         0   m  06-12
# 32   7.0  19.0  56kgs     Dewey   McDuck         0   m  12-18
# 45   7.0  19.0  56kgs     Dewey   McDuck        71   f   0-06
# 58   7.0  19.0  56kgs     Dewey   McDuck        78   f  06-12
# 71   7.0  19.0  56kgs     Dewey   McDuck        75   f  12-18
# 7    8.0  32.0  78kgs    Scööpy      Doo        78   m  00-06
# 20   8.0  32.0  78kgs    Scööpy      Doo        76   m  06-12
# 33   8.0  32.0  78kgs    Scööpy      Doo        75   m  12-18
# 46   8.0  32.0  78kgs    Scööpy      Doo         0   f   0-06
# 59   8.0  32.0  78kgs    Scööpy      Doo         0   f  06-12
# 72   8.0  32.0  78kgs    Scööpy      Doo         0   f  12-18
# 8    9.0  52.0  85kgs      Huey   McDuck         0   m  00-06
# 21   9.0  52.0  85kgs      Huey   McDuck         0   m  06-12
# 34   9.0  52.0  85kgs      Huey   McDuck         0   m  12-18
# 47   9.0  52.0  85kgs      Huey   McDuck        68   f   0-06
# 60   9.0  52.0  85kgs      Huey   McDuck        75   f  06-12
# 73   9.0  52.0  85kgs      Huey   McDuck        72   f  12-18
# 9   10.0  12.0  45kgs     Louie   McDuck         0   m  00-06
# 22  10.0  12.0  45kgs     Louie   McDuck         0   m  06-12
# 35  10.0  12.0  45kgs     Louie   McDuck         0   m  12-18
# 48  10.0  12.0  45kgs     Louie   McDuck        92   f   0-06
# 61  10.0  12.0  45kgs     Louie   McDuck        95   f  06-12
# 74  10.0  12.0  45kgs     Louie   McDuck        87   f  12-18

# %%
df = df.reset_index(drop=True)
df
# Out:
#       ID   Age Weight Firstname Lastname PulseRate Sex   Time
# 0    1.0  56.0  70kgs    Mickéy    Mousé        72   m  00-06
# 1    1.0  56.0  70kgs    Mickéy    Mousé        69   m  06-12
# 2    1.0  56.0  70kgs    Mickéy    Mousé        71   m  12-18
# 3    1.0  56.0  70kgs    Mickéy    Mousé         0   f   0-06
# 4    1.0  56.0  70kgs    Mickéy    Mousé         0   f  06-12
# 5    1.0  56.0  70kgs    Mickéy    Mousé         0   f  12-18
# 6    2.0  34.0  70kgs    Donald     Duck         0   m  00-06
# 7    2.0  34.0  70kgs    Donald     Duck         0   m  06-12
# 8    2.0  34.0  70kgs    Donald     Duck         0   m  12-18
# 9    2.0  34.0  70kgs    Donald     Duck        85   f   0-06
# 10   2.0  34.0  70kgs    Donald     Duck        84   f  06-12
# 11   2.0  34.0  70kgs    Donald     Duck        76   f  12-18
# 12   5.0  54.0  90kgs      Pink  Panther         0   m  00-06
# 13   5.0  54.0  90kgs      Pink  Panther         0   m  06-12
# 14   5.0  54.0  90kgs      Pink  Panther         0   m  12-18
# 15   5.0  54.0  90kgs      Pink  Panther        69   f   0-06
# 16   5.0  54.0  90kgs      Pink  Panther        75   f  12-18
# 17   6.0  52.0  85kgs      Huey   McDuck         0   m  00-06
# 18   6.0  52.0  85kgs      Huey   McDuck         0   m  06-12
# 19   6.0  52.0  85kgs      Huey   McDuck         0   m  12-18
# 20   6.0  52.0  85kgs      Huey   McDuck        68   f   0-06
# 21   6.0  52.0  85kgs      Huey   McDuck        75   f  06-12
# 22   6.0  52.0  85kgs      Huey   McDuck        72   f  12-18
# 23   7.0  19.0  56kgs     Dewey   McDuck         0   m  00-06
# 24   7.0  19.0  56kgs     Dewey   McDuck         0   m  06-12
# 25   7.0  19.0  56kgs     Dewey   McDuck         0   m  12-18
# 26   7.0  19.0  56kgs     Dewey   McDuck        71   f   0-06
# 27   7.0  19.0  56kgs     Dewey   McDuck        78   f  06-12
# 28   7.0  19.0  56kgs     Dewey   McDuck        75   f  12-18
# 29   8.0  32.0  78kgs    Scööpy      Doo        78   m  00-06
# 30   8.0  32.0  78kgs    Scööpy      Doo        76   m  06-12
# 31   8.0  32.0  78kgs    Scööpy      Doo        75   m  12-18
# 32   8.0  32.0  78kgs    Scööpy      Doo         0   f   0-06
# 33   8.0  32.0  78kgs    Scööpy      Doo         0   f  06-12
# 34   8.0  32.0  78kgs    Scööpy      Doo         0   f  12-18
# 35   9.0  52.0  85kgs      Huey   McDuck         0   m  00-06
# 36   9.0  52.0  85kgs      Huey   McDuck         0   m  06-12
# 37   9.0  52.0  85kgs      Huey   McDuck         0   m  12-18
# 38   9.0  52.0  85kgs      Huey   McDuck        68   f   0-06
# 39   9.0  52.0  85kgs      Huey   McDuck        75   f  06-12
# 40   9.0  52.0  85kgs      Huey   McDuck        72   f  12-18
# 41  10.0  12.0  45kgs     Louie   McDuck         0   m  00-06
# 42  10.0  12.0  45kgs     Louie   McDuck         0   m  06-12
# 43  10.0  12.0  45kgs     Louie   McDuck         0   m  12-18
# 44  10.0  12.0  45kgs     Louie   McDuck        92   f   0-06
# 45  10.0  12.0  45kgs     Louie   McDuck        95   f  06-12
# 46  10.0  12.0  45kgs     Louie   McDuck        87   f  12-18

# %%
df.to_csv('patient_heart_rate_clean.csv', index=False)
